# %% [raw]
# ---
# layout: post
# title: Learning HTML
# description:  Learn how to use html for your projects
# type: issues
# comments: true
# ---

# %% [markdown]
# HTML is the standard markup language for creating Web pages.

# %% [markdown]
# HTML stands for HyperText Markup Language. It is a standard markup language for web page creation. It allows the creation and structure of sections, paragraphs, and links using HTML elements (the building blocks of a web page) such as tags and attributes.
#
# HTML has a lot of use cases, namely:
#
# Web development. Developers use HTML code to design how a browser displays web page elements, such as text, hyperlinks, and media files.
# Internet navigation. Users can easily navigate and insert links between related pages and websites as HTML is heavily used to embed hyperlinks.
# Web documentation. HTML makes it possible to organize and format documents, similarly to Microsoft Word.
# It’s also worth noting that HTML is not considered a programming language as it can’t create dynamic functionality, although it is now considered an official web standard. The World Wide Web Consortium (W3C) maintains and develops HTML specifications, along with providing regular updates.
#
# The average website includes several different HTML pages. For instance, a home page, an about page, and a contact page would all have separate HTML files.
#
# HTML documents are files that end with a .html or .htm extension. A web browser reads the HTML file and renders its content so that internet users can view it.
#
# All HTML pages have a series of HTML elements, consisting of a set of tags and attributes. HTML elements are the building blocks of a web page. A tag tells the web browser where an element begins and ends, whereas an attribute describes the characteristics of an element.

# %% [markdown]
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Button in a Wider Box with Text</title>
#     <style>
#         /* Styling the container (box) */
#         .box {
#             width: 500px;
#             padding: 20px;
#             border: 2px solid #333;
#             border-radius: 10px;
#             box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);
#             margin: 50px auto;
#             background-color: #f9f9f9;
#             float: left;
#             clear: both;
#         }
#
#         /* Button styling */
#         button {
#             padding: 10px 20px;
#             font-size: 16px;
#             cursor: pointer;
#             margin-top: 10px;
#             background-color: purple;
#             color: white;
#             border: none;
#             border-radius: 5px;
#             float: left;
#         }
#
#         /* Button hover effect */
#         button:hover {
#             background-color: darkviolet;
#         }
#
#         #hiddenText {
#             display: none;
#             margin-top: 20px;
#             font-size: 18px;
#             color: #333;
#         }
#
#         /* Link styling (optional) */
#         a {
#             color: blue;
#             text-decoration: underline;
#         }
#
#         /* Clear floats after the button */
#         .clearfix::after {
#             content: "";
#             clear: both;
#             display: table;
#         }
#     </style>
# </head>
# <body>
#
#     <!-- Box container -->
#     <div class="box clearfix">
#         <!-- Text above the button -->
#         <p>You can learn more over here:</p>
#
#         <!-- Button aligned to the left -->
#         <button onclick="showText()">Click Me!</button>
#
#         <!-- Hidden text containing the link -->
#         <p id="hiddenText" style="clear: both;">
#             <a href="https://www.w3schools.com/html/default.asp" target="_blank">
#                 Visit W3Schools HTML Page
#             </a>
#         </p>
#     </div>
#
#     <script>
#         function showText() {
#             var text = document.getElementById("hiddenText");
#             if (text.style.display === "none" || text.style.display === "") {
#                 text.style.display = "block"; // Show the text
#             } else {
#                 text.style.display = "none"; // Hide the text
#             }
#         }
#     </script>
#
# </body>

# %% [markdown]
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Links Box</title>
#     <style>
#         .links-box {
#             width: 500px; /* The width of the box */
#             padding: 20px;
#             border: 2px solid #FF00FF;
#             border-radius: 10px;
#             box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);
#             margin: 50px 0; /* Top margin, no margin on the sides */
#             background-color: #F5F5F5;
#             margin-top: 300px;
#         }
#
#         /* Styling for links inside the second box */
#         .links-box a {
#             display: block; /* Make links stack vertically */
#             margin-bottom: 10px; /* Space between links */
#             font-size: 18px;
#             color: #00796b; /* Dark teal color */
#         }
#
#         /* Styling for the text below the links */
#         .links-box p {
#             font-size: 16px;
#             color: #004d40; /* Darker teal color */
#             margin-top: 10px;
#         }
#     </style>
# </head>
# <body>
#
#     <!-- Second box with links and text below them -->
#     <div class="links-box">
#         <a href="https://www.youtube.com/" target="_blank">Youtube</a>
#         <a href="https://html.com/" target="_blank">HTML.com</a>
#         <p>These are two websites where you can search for more content</p>
#     </div>
#
# </body>

# %% [markdown]
# Sources:
#
# <a href="https://www.hostinger.com/tutorials/what-is-html">What is HTML</a>
